# %%
import matplotlib as mpl
import numpy as np
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Initialize an empty list to hold DataFrames
frames = []

# Assuming file names are in the format 'participant1.csv', 'participant2.csv', etc.
# Adjust the range as per the number of participants
for i in range(1, 9):  # Change 9 to a higher number if you have more participants
    file_name = f'../data/p{i}/p{i}_main.csv'  # Constructs the file name
    df = pd.read_csv(file_name)  # Reads the file into a DataFrame
    df['Participant'] = i  # Adds the participant number
    frames.append(df)  # Appends the DataFrame to the list

# Concatenate all data frames
combined_df = pd.concat(frames, ignore_index=True)

# Now combined_df is your final DataFrame
combined_df.sample(5)
# Out:
#       trial_num  move_times  elbow_start_volts  elbow_start_pix  \
# 1305        106    0.303820           4.170956     -1619.042629
# 707         228    1.008034           4.179656     -1691.509921
# 1489         50    0.692221           4.205434     -1688.475972
# 1014         55    0.794121           4.232824     -1689.521152
# 957         238    1.022165           4.241846     -1695.190924
#
#       elbow_start_cm  elbow_start_deg  elbow_end_volts  elbow_end_pix  \
# 1305      -50.402847        74.937470         4.168056   -1610.693603
# 707       -52.658845        74.333976         3.593202    -169.149420
# 1489      -52.564395        72.545846         3.598036    -111.422988
# 1014      -52.596933        70.645958         3.514257     175.212271
# 957       -52.773440        70.020112         3.681170    -261.718660
#
#       elbow_end_cm  elbow_end_deg  ...  full_feedback  terminal_feedback  \
# 1305    -50.142931      75.160739  ...              0                  0
# 707      -5.265836     115.044897  ...              0                  0
# 1489     -3.468739     114.719352  ...              0                  1
# 1014      5.454580     120.512606  ...              0                  0
# 957      -8.147633     108.983371  ...              0                  0
#
#       rotation_direction  rotation  rotation_angle clamp  clamp_angle  \
# 1305                   0         0               0     0            0
# 707                    0         0               0     0            0
# 1489                   0         0               0     0            0
# 1014                   0         0               0     0            0
# 957                    0         0               0     0            0
#
#       vibration  trial_type  Participant
# 1305          2           0            6
# 707           3           0            3
# 1489          0           0            7
# 1014          0           0            5
# 957           0           0            4
#
# [5 rows x 33 columns]
